# %%
from urllib.parse import urlparse, urlunparse, urlencode
from urllib.request import urlretrieve
from pathlib import Path
import pandas as pd

import matplotlib.pyplot as plt
import re
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# Connet to Google Drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# %%
df = pd.read_csv('/content/gdrive/MyDrive/magisterka/finaldataset.csv', header=None, delimiter = "|", error_bad_lines=False)
#df.sheet_names

print(df.groupby(1)[0].nunique())
print(df.groupby(2)[0].nunique())
print(df.groupby(2)[1].nunique())
print(df.groupby(3)[0].nunique())
dict(zip(df[1],df[2]))
df.head(500)

# %%
def split_to_train_test(df, label_column, train_frac=0.85):
    train_df, test_df = pd.DataFrame(), pd.DataFrame()
    labels = df[label_column].unique()
    for lbl in labels:
        lbl_df = df[df[label_column] == lbl]
        lbl_train_df = lbl_df.sample(frac=train_frac)
        lbl_test_df = lbl_df.drop(lbl_train_df.index)
        train_df = train_df.append(lbl_train_df)
        test_df = test_df.append(lbl_test_df)

    return train_df, test_df

# %%
## USE TO DELETE IMAGES

df = pd.read_csv('/content/gdrive/MyDrive/magisterka/datasetv3.csv', header=None, delimiter = "|", error_bad_lines=False)
#df.sheet_names
df[1] = df[1].replace(['Elisabeth'],'Elizabeth')
df[1] = df[1].replace(['Antoninian Gordian III'],'Gordian III')
df.drop(df.loc[df[1]=='Francis II'].index, inplace=True)
df.drop(df.loc[df[1]=='Gordian III'].index, inplace=True)
df.drop(df.loc[df[1]=='Philip II'].index, inplace=True)

df.loc[df[1]=='Aurelian', 4] = 270
df.loc[df[1]=='Constantine the Great', 4] = 337
df.loc[df[1]=='Hadrian', 4] = 117
df.loc[df[1]=='Philip I', 4] = 244
df.loc[df[1]=='Trajan', 4] = 98



df.drop(df.loc[df[5]=='Alexander III__image01651.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Leopold I__image00035.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Leopold I__image00090.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Leopold I__image00098.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Leopold V__image02180.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Philip I__image97014.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Nicholas II__image01707.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Philip I__image97208.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Nicholas II__image01707.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Philip I__image97210.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Philip I__image97211.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Philip I__image97212.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Philip I__image99008.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Philip I__image99224.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Ferdinand II__image07472.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='4480__image07223.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Friedrich Wilhelm II__image01073.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Sigismund I Old__image00021.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Sigismund I Old__image00743.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Constantine the Great__image00179.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Constantine the Great__image00182.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Constantine the Great__image00183.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Constantine the Great__image00738.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Trajan__image99010.jpg'].index, inplace=True)
df.drop(df.loc[df[5]=='Nicholas II__image00288.jpg'].index, inplace=True)
df = df.drop_duplicates(subset=[6])
df = df[df.groupby(1)[1].transform('count').ge(25)]

df.to_csv('/content/gdrive/MyDrive/magisterka/finaldataset.csv', sep = "|", index=False, header = False)
df = pd.read_csv('/content/gdrive/MyDrive/magisterka/finaldataset.csv', header=None, delimiter = "|", error_bad_lines=False)

print(df.groupby(1)[0].nunique())
print(df.groupby(2)[0].nunique())
print(df.groupby(2)[1].nunique())

# %%
train,test = split_to_train_test(df,1)

print(train.groupby(1)[0].nunique())
print(train.groupby(2)[0].nunique())
print(train.groupby(2)[1].nunique())
print(train.groupby(0)[0].nunique())

print(test.groupby(1)[0].nunique())
print(test.groupby(2)[0].nunique())
print(test.groupby(2)[1].nunique())
print(test.groupby(0)[0].nunique())

for index, row in train.iterrows():
  Path("/content/gdrive/MyDrive/magisterka/coins_country/train/{}".format(row[2])).mkdir(parents=True, exist_ok=True)
  urlretrieve(row[6],  "/content/gdrive/MyDrive/magisterka/coins_country/train/{}/{}".format(row[2], row[2]+"__"+row[5]))

  Path("/content/gdrive/MyDrive/magisterka/coins_kings/train/{}".format(row[1])).mkdir(parents=True, exist_ok=True)
  urlretrieve(row[6],  "/content/gdrive/MyDrive/magisterka/coins_kings/train/{}/{}".format(row[1], row[2]+"__"+row[5]))

for index, row in test.iterrows():
  Path("/content/gdrive/MyDrive/magisterka/coins_country/test/{}".format(row[2])).mkdir(parents=True, exist_ok=True)
  urlretrieve(row[6],  "/content/gdrive/MyDrive/magisterka/coins_country/test/{}/{}".format(row[2], row[2]+"__"+row[5]))

  Path("/content/gdrive/MyDrive/magisterka/coins_kings/test/{}".format(row[1])).mkdir(parents=True, exist_ok=True)
  urlretrieve(row[6],  "/content/gdrive/MyDrive/magisterka/coins_kings/test/{}/{}".format(row[1], row[2]+"__"+row[5]))

train.to_csv('/content/gdrive/MyDrive/magisterka/train_dataset.csv', sep = "|", index=False, header = False)
test.to_csv('/content/gdrive/MyDrive/magisterka/test_dataset.csv', sep = "|", index=False, header = False)

# %%
# !cd gdrive/My Drive/magisterka
# !zip -r coins_country.zip coins_country/
# !zip -r coins_kings.zip coins_kings/

# %%
folds = []
rest,fold = split_to_train_test(df,1,train_frac=0.8)
folds.append(fold)

rest,fold = split_to_train_test(rest,1,train_frac=0.75)
folds.append(fold)
rest,fold = split_to_train_test(rest,1,train_frac=0.666)
folds.append(fold)
rest,fold = split_to_train_test(rest,1,train_frac=0.5)
folds.append(fold)
folds.append(rest)
print(len(df))
for i, fold in enumerate(folds):
  #print(fold.groupby(1)[0].nunique())
  print(fold.groupby(2)[0].nunique())
  print(fold.groupby(2)[1].nunique())
  print(len(fold))
 # print(fold.groupby(0)[0].nunique())
  print(".......................")
  for index, row in fold.iterrows():
    Path("/content/gdrive/MyDrive/magisterka/coins_country_fold{}/{}".format(i+1,row[2])).mkdir(parents=True, exist_ok=True)
    urlretrieve(row[6],  "/content/gdrive/MyDrive/magisterka/coins_country_fold{}/{}/{}".format(i+1,row[2], row[2]+"__"+row[5]))

    Path("/content/gdrive/MyDrive/magisterka/coins_kings_fold{}/{}".format(i+1,row[1])).mkdir(parents=True, exist_ok=True)
    urlretrieve(row[6],  "/content/gdrive/MyDrive/magisterka/coins_kings_fold{}/{}/{}".format(i+1,row[1], row[2]+"__"+row[5]))

  fold.to_csv('/content/gdrive/MyDrive/magisterka/train_dataset_fold{}.csv'.format(i+1), sep = "|", index=False, header = False)

# %%
cd gdrive/My Drive/magisterka

# %%
# !zip -r coins_country_fold1.zip coins_country_fold1/
# !zip -r coins_kings_fold1.zip coins_kings_fold1/

# !zip -r coins_country_fold2.zip coins_country_fold2/
# !zip -r coins_kings_fold2.zip coins_kings_fold2/

# !zip -r coins_country_fold3.zip coins_country_fold3/
# !zip -r coins_kings_fold3.zip coins_kings_fold3/

# !zip -r coins_country_fold4.zip coins_country_fold4/
# !zip -r coins_kings_fold4.zip coins_kings_fold4/

# !zip -r coins_country_fold5.zip coins_country_fold5/
# !zip -r coins_kings_fold5.zip coins_kings_fold5/
